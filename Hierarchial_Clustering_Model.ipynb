# %%
# Hierarchical Clustering

# %%
mergings = linkage(rfm_df_scaled, method='single', metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# Complete linkage

mergings = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# Average linkage

mergings = linkage(rfm_df_scaled, method="average", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
#Using the average method for the final clustering
# 3 clusters
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Assign cluster labels

rfm['Cluster_Labels'] = cluster_labels
rfm.head()
# Out:
#   CustomerID   Amount  Frequency  Recency  Cluster_Id  Cluster_Labels
# 0    12346.0     0.00          2      325           0               0
# 1    12347.0  4310.00        182        1           1               0
# 2    12348.0  1797.24         31       74           2               0
# 3    12349.0  1757.55         73       18           2               0
# 4    12350.0   334.40         17      309           0               0

# %%
# Plot Cluster Id vs Amount

sns.boxplot(x='Cluster_Labels', y='Amount', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Amount'>

# %%
# Plot Cluster Id vs Frequency

sns.boxplot(x='Cluster_Labels', y='Frequency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Frequency'>

# %%
# Plot Cluster Id vs Recency

sns.boxplot(x='Cluster_Labels', y='Recency', data=rfm)
# Out:
# <Axes: xlabel='Cluster_Labels', ylabel='Recency'>

# %%
from sklearn.metrics import silhouette_score

# Assuming rfm_df_scaled is your scaled data and cluster_labels are the labels you obtained from hierarchical clustering
silhouette_avg = silhouette_score(rfm_df_scaled, cluster_labels)
print("For n_clusters =", 3, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 3 The average silhouette_score is : 0.5812590418480046
